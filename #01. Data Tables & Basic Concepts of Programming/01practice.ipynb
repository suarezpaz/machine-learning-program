# %% [markdown]
# <font size="+5">#01. Data Tables, Plots & Basic Concepts of Programming</font>

# %% [markdown]
# <ul>
#     <li>Doubts? → Ask me in <img src="https://emoji.gg/assets/emoji/3970-discord.png" style="height: 1em; vertical-align: middle;"> <a href="https://discord.gg/cmB3KGsqMy">Discord</a></li>
#     <li>Tutorials → <img src="https://openmoji.org/php/download_asset.php?type=emoji&emoji_hexcode=E044&emoji_variant=color" style="height: 1em; vertical-align: middle;"> <a href="https://www.youtube.com/channel/UCovCte2I3loteQE_kRsfQcw">YouTube</a></li>
#     <li>Book Private Lessons → <span style="color: orange">@</span> <a href="https://sotastica.com/reservar">sotastica</a></li>
# </ul>

# %% [markdown]
# # Discipline to Search Solutions in Google

# %% [markdown]
# > Apply the following steps when **looking for solutions in Google**:
# >
# > 1. **Necesity**: How to load an Excel in Python?
# > 2. **Search in Google**: by keywords
# >   - `load excel python`
# >   - ~~how to load excel in python~~
# > 3. **Solution**: What's the `function()` that loads an Excel in Python?
# >   - A Function to Programming is what the Atom to Phisics.
# >   - Every time you want to do something in programming
# >   - **You will need a `function()`** to make it
# >   - Theferore, you must **detect parenthesis `()`**
# >   - Out of all the words that you see in a website
# >   - Because they indicate the presence of a `function()`.

# %% [markdown]
# # Load the Data

# %%
import pandas as pd

df = pd.read_excel('df_mortality_regions.xlsx', index_col=0)
df.head()


# Islands
# Out:
#              Regional indicator  Population 2020  Population 2019  \
# Country name
# Finland          Western Europe        5540718.0        5520314.0
# Denmark          Western Europe        5792203.0        5818553.0
# Switzerland      Western Europe        8654618.0        8574832.0
# Iceland          Western Europe         341250.0         361313.0
# Netherlands      Western Europe       17134873.0       17332850.0
#
#               COVID-19 deaths per 100,000 population in 2020  Median age  \
# Country name
# Finland                                            10.125000   42.799999
# Denmark                                            22.409399   42.299999
# Switzerland                                        88.334305   43.099998
# Iceland                                             8.498200   37.299999
# Netherlands                                        67.260498   43.200001
#
#               Island  \
# Country name
# Finland            0
# Denmark            0
# ...

# %%
type([])
# Out:
# list

# %%
type(89)
# Out:
# int

# %%
type('hola')
# Out:
# str

# %%
columnas = ['Regional indicator', 'Population 2019']

# %%
columnas
# Out:
# ['Regional indicator', 'Population 2019']

# %%
columnas.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-8ea752f3576f> in <module>
# ----> 1 columnas.describe()
#
# AttributeError: 'list' object has no attribute 'describe'

# %%
df[columnas].describe()
# Out:
#        Population 2019
# count     1.470000e+02
# mean      5.023767e+07
# std       1.651070e+08
# min       3.613130e+05
# 25%       5.197728e+06
# 50%       1.151310e+07
# 75%       3.703052e+07
# max       1.397715e+09

# %%
df."Regional indicator".value_counts().plot(Kind='pie')
# Out:
#   File "<ipython-input-34-6579b04da101>", line 1
#     df."Regional indicator".value_counts().plot(Kind='pie')
#        ^
# SyntaxError: invalid syntax

# %%
df['Regional indicator'].value_counts()
# Out:
# Sub-Saharan Africa                    35
# Western Europe                        21
# Latin America and Caribbean           20
# Central and Eastern Europe            17
# Middle East and North Africa          17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: Regional indicator, dtype: int64

# %%
df['Regional indicator'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Regional indicator'>

# %%
df."Regional indicator".value_counts().plot(Kind='pie')
# Out:
#   File "<ipython-input-37-6579b04da101>", line 1
#     df."Regional indicator".value_counts().plot(Kind='pie')
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Which region had more Islands?

# %%
df.Island.value_counts()
# Out:
# 0    128
# 1     20
# Name: Island, dtype: int64

# %%
mask = df.Island>0

# %%
df[df.Island>0]
# Out:
#                               Regional indicator  Population 2020  \
# Country name
# Iceland                           Western Europe         341250.0
# New Zealand                North America and ANZ        4822233.0
# Australia                  North America and ANZ       25499881.0
# Ireland                           Western Europe        4937796.0
# United Kingdom                    Western Europe       67886004.0
# Bahrain             Middle East and North Africa        1701583.0
# Malta                             Western Europe         441539.0
# Singapore                         Southeast Asia        5850343.0
# Jamaica              Latin America and Caribbean        2961161.0
# Cyprus                            Western Europe         875899.0
# Mauritius                     Sub-Saharan Africa        1271767.0
# Japan                                  East Asia      126476458.0
# Philippines                       Southeast Asia      109581085.0
# ...

# %%
df[mask]
# Out:
#                               Regional indicator  Population 2020  \
# Country name
# Iceland                           Western Europe         341250.0
# New Zealand                North America and ANZ        4822233.0
# Australia                  North America and ANZ       25499881.0
# Ireland                           Western Europe        4937796.0
# United Kingdom                    Western Europe       67886004.0
# Bahrain             Middle East and North Africa        1701583.0
# Malta                             Western Europe         441539.0
# Singapore                         Southeast Asia        5850343.0
# Jamaica              Latin America and Caribbean        2961161.0
# Cyprus                            Western Europe         875899.0
# Mauritius                     Sub-Saharan Africa        1271767.0
# Japan                                  East Asia      126476458.0
# Philippines                       Southeast Asia      109581085.0
# ...

# %%
df[mask]
# Out:
#                               Regional indicator  Population 2020  \
# Country name
# Iceland                           Western Europe         341250.0
# New Zealand                North America and ANZ        4822233.0
# Australia                  North America and ANZ       25499881.0
# Ireland                           Western Europe        4937796.0
# United Kingdom                    Western Europe       67886004.0
# Bahrain             Middle East and North Africa        1701583.0
# Malta                             Western Europe         441539.0
# Singapore                         Southeast Asia        5850343.0
# Jamaica              Latin America and Caribbean        2961161.0
# Cyprus                            Western Europe         875899.0
# Mauritius                     Sub-Saharan Africa        1271767.0
# Japan                                  East Asia      126476458.0
# Philippines                       Southeast Asia      109581085.0
# ...

# %%
df[df.Island>0]['Regional indicator']
# Out:
# Country name
# Iceland                             Western Europe
# New Zealand                  North America and ANZ
# Australia                    North America and ANZ
# Ireland                             Western Europe
# United Kingdom                      Western Europe
# Bahrain               Middle East and North Africa
# Malta                               Western Europe
# Singapore                           Southeast Asia
# Jamaica                Latin America and Caribbean
# Cyprus                              Western Europe
# Mauritius                       Sub-Saharan Africa
# Japan                                    East Asia
# Philippines                         Southeast Asia
# Dominican Republic     Latin America and Caribbean
# Indonesia                           Southeast Asia
# Maldives                                South Asia
# Sri Lanka                               South Asia
# Comoros                         Sub-Saharan Africa
# ...

# %%
df[df.Island>0]['Regional indicator'].value_counts()
# Out:
# Western Europe                  5
# Southeast Asia                  3
# Sub-Saharan Africa              3
# Latin America and Caribbean     3
# North America and ANZ           2
# South Asia                      2
# East Asia                       1
# Middle East and North Africa    1
# Name: Regional indicator, dtype: int64

# %%
pd.read_csv('´hola.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-56-96a41695b8cd> in <module>
# ----> 1 pd.read_csv('´hola.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
df['Regional indicator']
# Out:
# Country name
# Finland            Western Europe
# Denmark            Western Europe
# Switzerland        Western Europe
# Iceland            Western Europe
# Netherlands        Western Europe
#                       ...
# Lesotho        Sub-Saharan Africa
# Botswana       Sub-Saharan Africa
# Rwanda         Sub-Saharan Africa
# Zimbabwe       Sub-Saharan Africa
# Afghanistan            South Asia
# Name: Regional indicator, Length: 148, dtype: object

# %%
df[df.Island==1]['Regional indicator'].value_counts()
# Out:
# Western Europe                  5
# Southeast Asia                  3
# Sub-Saharan Africa              3
# Latin America and Caribbean     3
# North America and ANZ           2
# South Asia                      2
# East Asia                       1
# Middle East and North Africa    1
# Name: Regional indicator, dtype: int64

# %%
df.Island==1
# Out:
# Country name
# Finland        False
# Denmark        False
# Switzerland    False
# Iceland         True
# Netherlands    False
#                ...
# Lesotho        False
# Botswana       False
# Rwanda         False
# Zimbabwe       False
# Afghanistan    False
# Name: Island, Length: 148, dtype: bool

# %%
df[df.Island==1]
# Out:
#                               Regional indicator  Population 2020  \
# Country name
# Iceland                           Western Europe         341250.0
# New Zealand                North America and ANZ        4822233.0
# Australia                  North America and ANZ       25499881.0
# Ireland                           Western Europe        4937796.0
# United Kingdom                    Western Europe       67886004.0
# Bahrain             Middle East and North Africa        1701583.0
# Malta                             Western Europe         441539.0
# Singapore                         Southeast Asia        5850343.0
# Jamaica              Latin America and Caribbean        2961161.0
# Cyprus                            Western Europe         875899.0
# Mauritius                     Sub-Saharan Africa        1271767.0
# Japan                                  East Asia      126476458.0
# Philippines                       Southeast Asia      109581085.0
# ...

# %%
df[df.Island==1]['Regional indicator']
# Out:
# Country name
# Iceland                             Western Europe
# New Zealand                  North America and ANZ
# Australia                    North America and ANZ
# Ireland                             Western Europe
# United Kingdom                      Western Europe
# Bahrain               Middle East and North Africa
# Malta                               Western Europe
# Singapore                           Southeast Asia
# Jamaica                Latin America and Caribbean
# Cyprus                              Western Europe
# Mauritius                       Sub-Saharan Africa
# Japan                                    East Asia
# Philippines                         Southeast Asia
# Dominican Republic     Latin America and Caribbean
# Indonesia                           Southeast Asia
# Maldives                                South Asia
# Sri Lanka                               South Asia
# Comoros                         Sub-Saharan Africa
# ...

# %%
df[df.Island==1]['Regional indicator'].value_counts()
# Out:
# Western Europe                  5
# Southeast Asia                  3
# Sub-Saharan Africa              3
# Latin America and Caribbean     3
# North America and ANZ           2
# South Asia                      2
# East Asia                       1
# Middle East and North Africa    1
# Name: Regional indicator, dtype: int64

# %% [markdown]
# ## Show all Columns for these Islands

# %%
'Regional indicator'=='Western Europe'
# Out:
# False

# %%
Europa=df['Regional indicator']=='Western Europe'

# %%
island=df['Island']==1

# %%
df[island]
# Out:
#                               Regional indicator  Population 2020  \
# Country name
# Iceland                           Western Europe         341250.0
# New Zealand                North America and ANZ        4822233.0
# Australia                  North America and ANZ       25499881.0
# Ireland                           Western Europe        4937796.0
# United Kingdom                    Western Europe       67886004.0
# Bahrain             Middle East and North Africa        1701583.0
# Malta                             Western Europe         441539.0
# Singapore                         Southeast Asia        5850343.0
# Jamaica              Latin America and Caribbean        2961161.0
# Cyprus                            Western Europe         875899.0
# Mauritius                     Sub-Saharan Africa        1271767.0
# Japan                                  East Asia      126476458.0
# Philippines                       Southeast Asia      109581085.0
# ...

# %%
df[island & Europa]
# Out:
#                Regional indicator  Population 2020  Population 2019  \
# Country name
# Iceland            Western Europe         341250.0         361313.0
# Ireland            Western Europe        4937796.0        4941444.0
# United Kingdom     Western Europe       67886004.0       66834405.0
# Malta              Western Europe         441539.0         502653.0
# Cyprus             Western Europe         875899.0        1198575.0
#
#                 COVID-19 deaths per 100,000 population in 2020  Median age  \
# Country name
# Iceland                                               8.498200   37.299999
# Ireland                                              45.303600   38.700001
# United Kingdom                                      108.449501   40.799999
# Malta                                                49.599201   42.400002
# Cyprus                                               13.586000   37.299999
#
#                 Island  \
# Country name
# Iceland              1
# ...

# %%
df[Europa]
# Out:
#                Regional indicator  Population 2020  Population 2019  \
# Country name
# Finland            Western Europe        5540718.0        5520314.0
# Denmark            Western Europe        5792203.0        5818553.0
# Switzerland        Western Europe        8654618.0        8574832.0
# Iceland            Western Europe         341250.0         361313.0
# Netherlands        Western Europe       17134873.0       17332850.0
# Norway             Western Europe        5421242.0        5347896.0
# Sweden             Western Europe       10099270.0       10285453.0
# Luxembourg         Western Europe         625976.0         619896.0
# Austria            Western Europe        9006400.0        8877067.0
# Germany            Western Europe       83783945.0       83132799.0
# Ireland            Western Europe        4937796.0        4941444.0
# United Kingdom     Western Europe       67886004.0       66834405.0
# Belgium            Western Europe       11589616.0       11484055.0
# ...

# %% [markdown]
# ## Mean Age of across All Islands?

# %%
df.head()
# Out:
#              Regional indicator  Population 2020  Population 2019  \
# Country name
# Finland          Western Europe        5540718.0        5520314.0
# Denmark          Western Europe        5792203.0        5818553.0
# Switzerland      Western Europe        8654618.0        8574832.0
# Iceland          Western Europe         341250.0         361313.0
# Netherlands      Western Europe       17134873.0       17332850.0
#
#               COVID-19 deaths per 100,000 population in 2020  Median age  \
# Country name
# Finland                                            10.125000   42.799999
# Denmark                                            22.409399   42.299999
# Switzerland                                        88.334305   43.099998
# Iceland                                             8.498200   37.299999
# Netherlands                                        67.260498   43.200001
#
#               Island  \
# Country name
# Finland            0
# Denmark            0
# ...

# %%
df[df.Island == 1]['Median age'].mean()
# Out:
# 33.76000032424927

# %%
df[df.Island == 0]['Median age'].mean()
# Out:
# 30.919047673543293

# %%
df.groupby('Island')['Median age'].mean()
# Out:
# Island
# 0    30.919048
# 1    33.760000
# Name: Median age, dtype: float64

# %% [markdown]
# # Female Heads of State

# %% [markdown]
# ## Number of Countries with Female Heads of State

# %%
# Out:
# 22

# %% [markdown]
# ## Which region had more Female Heads of State?

# %%
# Out:
# Regional indicator
# Western Europe                        6
# Central and Eastern Europe            5
# Sub-Saharan Africa                    4
# Southeast Asia                        2
# South Asia                            2
# North America and ANZ                 1
# East Asia                             1
# Commonwealth of Independent States    1
# Middle East and North Africa          0
# Latin America and Caribbean           0
# Name: Female head of government, dtype: int64

# %% [markdown]
# ## Show all Columns for these Countries

# %%
# Out:
#    Country name Regional indicator  Population 2020  Population 2019  \
# 0       Finland     Western Europe        5540718.0        5520314.0
# 1       Denmark     Western Europe        5792203.0        5818553.0
# 3       Iceland     Western Europe         341250.0         361313.0
# 5        Norway     Western Europe        5421242.0        5347896.0
# 12      Germany     Western Europe       83783945.0       83132799.0
# 67       Greece     Western Europe       10423056.0       10716322.0
#
#     COVID-19 deaths per 100,000 population in 2020  Median age  Island  \
# 0                                        10.125000   42.799999       0
# 1                                        22.409399   42.299999       0
# 3                                         8.498200   37.299999       1
# 5                                         8.042400   39.700001       0
# 12                                       40.331100   46.599998       0
# ...

# %% [markdown]
# ## Mean Age of across All Countries?

# %%
# Out:
# 42.33333269755045

# %% [markdown]
# ## Show All Columns for the Country with more deaths due to Covid per 100,000 people

# %%
df.loc[mask,:]
# Out:
# Country name                                                                          Belgium
# Regional indicator                                                             Western Europe
# Population 2020                                                                    11589616.0
# Population 2019                                                                    11484055.0
# COVID-19 deaths per 100,000 population in 2020                                     168.495697
# Median age                                                                          41.799999
# Island                                                                                      0
# Index of exposure to COVID-19  infections in other countries as of March 31          6.343308
# Log of average distance to SARS countries                                            9.071179
# WHO Western Pacific Region                                                                  0
# ...

# %% [markdown]
# # Achieved Goals

# %% [markdown]
# _Double click on **this cell** and place an `X` inside the square brackets (i.e., [X]) if you think you understand the goal:_
#
# - [ ] Identify the **Elements of Programming** thanks to the syntax.
# - [ ] Use `functions` that belongs to external `libraries`.
# - [ ] Get _the machine to work for you, not against you_.
#   - [ ] `shift + tab` to ask help to Python.
#   - [ ] `tab` to ask Python for suggestions.
# - [ ] Understand that a `dog` doesn't make `miau()`. But, rather `guau()`... the same way a `DataFrame` cannot `fly()` (i.e., `DataFrame.fly()`?).
# - [ ] All roads lead to Rome; We can achieve the **the same result with different lines of code**.
#   - We reproduced a scatterplot using 3 different lines of code.
